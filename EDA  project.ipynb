# %% [markdown]
# ## ICC Tournament History (1975–2025)

# %% [markdown]
# This dataset provides a comprehensive record of major ICC cricket tournaments, including the ODI World Cup, T20 World Cup, Champions Trophy, and World Test Championship. It covers details such as tournament type, year, host country, winners, runner‑ups, winning captains, final stadiums, margin of victory, and Player of the Match awards.
#
# Goal: Perform EDA to uncover cricket trends, dominance patterns, and key players.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
icc = pd.read_csv(r"C:\Users\Asus\Downloads\icc_complete_history.csv",index_col=0)
icc
# Out:
#                              Tournament_Type    Year  \
# Tournament_Category
# NaN                                      NaN     NaN
# ODI                            ODI World Cup  1975.0
# ODI                            ODI World Cup  1979.0
# ODI                            ODI World Cup  1983.0
# ODI                            ODI World Cup  1987.0
# ODI                            ODI World Cup  1992.0
# ODI                            ODI World Cup  1996.0
# ODI                            ODI World Cup  1999.0
# ODI                            ODI World Cup  2003.0
# ODI                            ODI World Cup  2007.0
# ODI                            ODI World Cup  2011.0
# ODI                            ODI World Cup  2015.0
# ODI                            ODI World Cup  2019.0
# ODI                            ODI World Cup  2023.0
# NaN                                      NaN     NaN
# T20                            T20 World Cup  2007.0
# T20                            T20 World Cup  2009.0
# T20                            T20 World Cup  2010.0
# T20                            T20 World Cup  2012.0
# T20                            T20 World Cup  2014.0
# T20                            T20 World Cup  2016.0
# T20                            T20 World Cup  2021.0
# T20                            T20 World Cup  2022.0
# T20                            T20 World Cup  2024.0
# NaN                                      NaN     NaN
# CT                          Champions Trophy  1998.0
# CT                          Champions Trophy  2000.0
# CT                          Champions Trophy  2002.0
# CT                          Champions Trophy  2004.0
# CT                          Champions Trophy  2006.0
# CT                          Champions Trophy  2009.0
# CT                          Champions Trophy  2013.0
# CT                          Champions Trophy  2017.0
# CT                          Champions Trophy  2025.0
# NaN                                      NaN     NaN
# WTC                  World Test Championship  2021.0
# WTC                  World Test Championship  2023.0
#
#                                     Host_Country           Winner  \
# Tournament_Category
# NaN                                          NaN              NaN
# ODI                                      England      West Indies
# ODI                                      England      West Indies
# ODI                                      England            India
# ODI                               India/Pakistan        Australia
# ODI                        Australia/New Zealand         Pakistan
# ODI                     India/Pakistan/Sri Lanka        Sri Lanka
# ODI                                      England        Australia
# ODI                  South Africa/Zimbabwe/Kenya        Australia
# ODI                                  West Indies        Australia
# ODI                   India/Sri Lanka/Bangladesh            India
# ODI                        Australia/New Zealand        Australia
# ODI                                England/Wales          England
# ODI                                        India        Australia
# NaN                                          NaN              NaN
# T20                                 South Africa            India
# T20                                      England         Pakistan
# T20                                  West Indies          England
# T20                                    Sri Lanka      West Indies
# T20                                   Bangladesh        Sri Lanka
# T20                                        India      West Indies
# T20                                     UAE/Oman        Australia
# T20                                    Australia          England
# T20                              USA/West Indies            India
# NaN                                          NaN              NaN
# CT                                    Bangladesh     South Africa
# CT                                         Kenya      New Zealand
# CT                                     Sri Lanka  India/Sri Lanka
# CT                                       England      West Indies
# CT                                         India        Australia
# CT                                  South Africa        Australia
# CT                                 England/Wales            India
# CT                                 England/Wales         Pakistan
# CT                                  Pakistan/UAE            India
# NaN                                          NaN              NaN
# WTC                                      England      New Zealand
# WTC                                      England        Australia
#
#                                 Runner_Up      Winning_Captain  \
# Tournament_Category
# NaN                                   NaN                  NaN
# ODI                             Australia          Clive Lloyd
# ODI                               England          Clive Lloyd
# ODI                           West Indies            Kapil Dev
# ODI                               England         Allan Border
# ODI                               England           Imran Khan
# ODI                             Australia     Arjuna Ranatunga
# ODI                              Pakistan          Steve Waugh
# ODI                                 India        Ricky Ponting
# ODI                             Sri Lanka        Ricky Ponting
# ODI                             Sri Lanka             MS Dhoni
# ODI                           New Zealand       Michael Clarke
# ODI                           New Zealand          Eoin Morgan
# ODI                                 India          Pat Cummins
# NaN                                   NaN                  NaN
# T20                              Pakistan             MS Dhoni
# T20                             Sri Lanka          Younis Khan
# T20                             Australia     Paul Collingwood
# T20                             Sri Lanka         Darren Sammy
# T20                                 India     Dinesh Chandimal
# T20                               England         Darren Sammy
# T20                           New Zealand          Aaron Finch
# T20                              Pakistan          Jos Buttler
# T20                          South Africa         Rohit Sharma
# NaN                                   NaN                  NaN
# CT                            West Indies        Hansie Cronje
# CT                                  India      Stephen Fleming
# CT                   None (Joint Winners)  R Premadasa Stadium
# CT                                England           Brian Lara
# CT                            West Indies        Ricky Ponting
# CT                            New Zealand        Ricky Ponting
# CT                                England             MS Dhoni
# CT                                  India       Sarfaraz Ahmed
# CT                            New Zealand         Rohit Sharma
# NaN                                   NaN                  NaN
# WTC                                 India      Kane Williamson
# WTC                                 India          Pat Cummins
#
#                                            Final_Stadium          Win_By  \
# Tournament_Category
# NaN                                                  NaN             NaN
# ODI                                Lord's Cricket Ground         17 Runs
# ODI                                Lord's Cricket Ground         92 Runs
# ODI                                Lord's Cricket Ground         43 Runs
# ODI                                         Eden Gardens          7 Runs
# ODI                             Melbourne Cricket Ground         22 Runs
# ODI                                      Gaddafi Stadium       7 Wickets
# ODI                                Lord's Cricket Ground       8 Wickets
# ODI                                New Wanderers Stadium        125 Runs
# ODI                                      Kensington Oval         53 Runs
# ODI                                     Wankhede Stadium       6 Wickets
# ODI                             Melbourne Cricket Ground       7 Wickets
# ODI                                Lord's Cricket Ground  Boundary Count
# ODI                                Narendra Modi Stadium       6 Wickets
# NaN                                                  NaN             NaN
# T20                                The Wanderers Stadium          5 Runs
# T20                                Lord's Cricket Ground       8 Wickets
# T20                                      Kensington Oval       7 Wickets
# T20                                  R Premadasa Stadium         36 Runs
# T20                                Sher-e-Bangla Stadium       6 Wickets
# T20                                         Eden Gardens       4 Wickets
# T20                          Dubai International Stadium       8 Wickets
# T20                             Melbourne Cricket Ground       5 Wickets
# T20                                      Kensington Oval          7 Runs
# NaN                                                  NaN             NaN
# CT                          Bangabandhu National Stadium       4 Wickets
# CT                                  Gymkhana Club Ground       4 Wickets
# CT                                         Shared Trophy             NaN
# CT                                              The Oval       2 Wickets
# CT                                     Brabourne Stadium       8 Wickets
# CT                                        Centurion Park       6 Wickets
# CT                                             Edgbaston          5 Runs
# CT                                              The Oval        180 Runs
# CT                   Dubai International Cricket Stadium       4 Wickets
# NaN                                                  NaN             NaN
# WTC                                            Rose Bowl       8 Wickets
# WTC                                             The Oval        209 Runs
#
#                     Player_of_the_Match
# Tournament_Category
# NaN                                 NaN
# ODI                         Clive Lloyd
# ODI                        Viv Richards
# ODI                   Mohinder Amarnath
# ODI                          David Boon
# ODI                         Wasim Akram
# ODI                   Aravinda de Silva
# ODI                         Shane Warne
# ODI                       Ricky Ponting
# ODI                      Adam Gilchrist
# ODI                            MS Dhoni
# ODI                      James Faulkner
# ODI                          Ben Stokes
# ODI                         Travis Head
# NaN                                 NaN
# T20                        Irfan Pathan
# T20                       Shahid Afridi
# T20                    Craig Kieswetter
# T20                      Marlon Samuels
# T20                    Kumar Sangakkara
# T20                      Marlon Samuels
# T20                      Mitchell Marsh
# T20                          Sam Curran
# T20                         Virat Kohli
# NaN                                 NaN
# CT                       Jacques Kallis
# CT                         Chris Cairns
# CT                                  NaN
# CT                         Ian Bradshaw
# CT                         Shane Watson
# CT                         Shane Watson
# CT                      Ravindra Jadeja
# CT                         Fakhar Zaman
# CT                         Rohit Sharma
# NaN                                 NaN
# WTC                       Kyle Jamieson
# WTC                         Travis Head

# %%
icc.describe()
# Out:
#               Year
# count    33.000000
# mean   2007.333333
# std      13.282194
# min    1975.000000
# 25%    2000.000000
# 50%    2009.000000
# 75%    2017.000000
# max    2025.000000

# %%
icc.isna().sum().sort_values(ascending=False)
# Out:
# Win_By                 5
# Player_of_the_Match    5
# Tournament_Type        4
# Year                   4
# Host_Country           4
# Winner                 4
# Runner_Up              4
# Winning_Captain        4
# Final_Stadium          4
# dtype: int64

# %%
df=icc.isna().sum().sort_values(ascending=False)/len(icc)*100
df
# Out:
# Win_By                 13.513514
# Player_of_the_Match    13.513514
# Tournament_Type        10.810811
# Year                   10.810811
# Host_Country           10.810811
# Winner                 10.810811
# Runner_Up              10.810811
# Winning_Captain        10.810811
# Final_Stadium          10.810811
# dtype: float64

# %%
## Dropping NaN Values
icc = icc.dropna(how = 'all')
icc
# Out:
#                              Tournament_Type    Year  \
# Tournament_Category
# ODI                            ODI World Cup  1975.0
# ODI                            ODI World Cup  1979.0
# ODI                            ODI World Cup  1983.0
# ODI                            ODI World Cup  1987.0
# ODI                            ODI World Cup  1992.0
# ODI                            ODI World Cup  1996.0
# ODI                            ODI World Cup  1999.0
# ODI                            ODI World Cup  2003.0
# ODI                            ODI World Cup  2007.0
# ODI                            ODI World Cup  2011.0
# ODI                            ODI World Cup  2015.0
# ODI                            ODI World Cup  2019.0
# ODI                            ODI World Cup  2023.0
# T20                            T20 World Cup  2007.0
# T20                            T20 World Cup  2009.0
# T20                            T20 World Cup  2010.0
# T20                            T20 World Cup  2012.0
# T20                            T20 World Cup  2014.0
# T20                            T20 World Cup  2016.0
# T20                            T20 World Cup  2021.0
# T20                            T20 World Cup  2022.0
# T20                            T20 World Cup  2024.0
# CT                          Champions Trophy  1998.0
# CT                          Champions Trophy  2000.0
# CT                          Champions Trophy  2002.0
# CT                          Champions Trophy  2004.0
# CT                          Champions Trophy  2006.0
# CT                          Champions Trophy  2009.0
# CT                          Champions Trophy  2013.0
# CT                          Champions Trophy  2017.0
# CT                          Champions Trophy  2025.0
# WTC                  World Test Championship  2021.0
# WTC                  World Test Championship  2023.0
#
#                                     Host_Country           Winner  \
# Tournament_Category
# ODI                                      England      West Indies
# ODI                                      England      West Indies
# ODI                                      England            India
# ODI                               India/Pakistan        Australia
# ODI                        Australia/New Zealand         Pakistan
# ODI                     India/Pakistan/Sri Lanka        Sri Lanka
# ODI                                      England        Australia
# ODI                  South Africa/Zimbabwe/Kenya        Australia
# ODI                                  West Indies        Australia
# ODI                   India/Sri Lanka/Bangladesh            India
# ODI                        Australia/New Zealand        Australia
# ODI                                England/Wales          England
# ODI                                        India        Australia
# T20                                 South Africa            India
# T20                                      England         Pakistan
# T20                                  West Indies          England
# T20                                    Sri Lanka      West Indies
# T20                                   Bangladesh        Sri Lanka
# T20                                        India      West Indies
# T20                                     UAE/Oman        Australia
# T20                                    Australia          England
# T20                              USA/West Indies            India
# CT                                    Bangladesh     South Africa
# CT                                         Kenya      New Zealand
# CT                                     Sri Lanka  India/Sri Lanka
# CT                                       England      West Indies
# CT                                         India        Australia
# CT                                  South Africa        Australia
# CT                                 England/Wales            India
# CT                                 England/Wales         Pakistan
# CT                                  Pakistan/UAE            India
# WTC                                      England      New Zealand
# WTC                                      England        Australia
#
#                                 Runner_Up      Winning_Captain  \
# Tournament_Category
# ODI                             Australia          Clive Lloyd
# ODI                               England          Clive Lloyd
# ODI                           West Indies            Kapil Dev
# ODI                               England         Allan Border
# ODI                               England           Imran Khan
# ODI                             Australia     Arjuna Ranatunga
# ODI                              Pakistan          Steve Waugh
# ODI                                 India        Ricky Ponting
# ODI                             Sri Lanka        Ricky Ponting
# ODI                             Sri Lanka             MS Dhoni
# ODI                           New Zealand       Michael Clarke
# ODI                           New Zealand          Eoin Morgan
# ODI                                 India          Pat Cummins
# T20                              Pakistan             MS Dhoni
# T20                             Sri Lanka          Younis Khan
# T20                             Australia     Paul Collingwood
# T20                             Sri Lanka         Darren Sammy
# T20                                 India     Dinesh Chandimal
# T20                               England         Darren Sammy
# T20                           New Zealand          Aaron Finch
# T20                              Pakistan          Jos Buttler
# T20                          South Africa         Rohit Sharma
# CT                            West Indies        Hansie Cronje
# CT                                  India      Stephen Fleming
# CT                   None (Joint Winners)  R Premadasa Stadium
# CT                                England           Brian Lara
# CT                            West Indies        Ricky Ponting
# CT                            New Zealand        Ricky Ponting
# CT                                England             MS Dhoni
# CT                                  India       Sarfaraz Ahmed
# CT                            New Zealand         Rohit Sharma
# WTC                                 India      Kane Williamson
# WTC                                 India          Pat Cummins
#
#                                            Final_Stadium          Win_By  \
# Tournament_Category
# ODI                                Lord's Cricket Ground         17 Runs
# ODI                                Lord's Cricket Ground         92 Runs
# ODI                                Lord's Cricket Ground         43 Runs
# ODI                                         Eden Gardens          7 Runs
# ODI                             Melbourne Cricket Ground         22 Runs
# ODI                                      Gaddafi Stadium       7 Wickets
# ODI                                Lord's Cricket Ground       8 Wickets
# ODI                                New Wanderers Stadium        125 Runs
# ODI                                      Kensington Oval         53 Runs
# ODI                                     Wankhede Stadium       6 Wickets
# ODI                             Melbourne Cricket Ground       7 Wickets
# ODI                                Lord's Cricket Ground  Boundary Count
# ODI                                Narendra Modi Stadium       6 Wickets
# T20                                The Wanderers Stadium          5 Runs
# T20                                Lord's Cricket Ground       8 Wickets
# T20                                      Kensington Oval       7 Wickets
# T20                                  R Premadasa Stadium         36 Runs
# T20                                Sher-e-Bangla Stadium       6 Wickets
# T20                                         Eden Gardens       4 Wickets
# T20                          Dubai International Stadium       8 Wickets
# T20                             Melbourne Cricket Ground       5 Wickets
# T20                                      Kensington Oval          7 Runs
# CT                          Bangabandhu National Stadium       4 Wickets
# CT                                  Gymkhana Club Ground       4 Wickets
# CT                                         Shared Trophy             NaN
# CT                                              The Oval       2 Wickets
# CT                                     Brabourne Stadium       8 Wickets
# CT                                        Centurion Park       6 Wickets
# CT                                             Edgbaston          5 Runs
# CT                                              The Oval        180 Runs
# CT                   Dubai International Cricket Stadium       4 Wickets
# WTC                                            Rose Bowl       8 Wickets
# WTC                                             The Oval        209 Runs
#
#                     Player_of_the_Match
# Tournament_Category
# ODI                         Clive Lloyd
# ODI                        Viv Richards
# ODI                   Mohinder Amarnath
# ODI                          David Boon
# ODI                         Wasim Akram
# ODI                   Aravinda de Silva
# ODI                         Shane Warne
# ODI                       Ricky Ponting
# ODI                      Adam Gilchrist
# ODI                            MS Dhoni
# ODI                      James Faulkner
# ODI                          Ben Stokes
# ODI                         Travis Head
# T20                        Irfan Pathan
# T20                       Shahid Afridi
# T20                    Craig Kieswetter
# T20                      Marlon Samuels
# T20                    Kumar Sangakkara
# T20                      Marlon Samuels
# T20                      Mitchell Marsh
# T20                          Sam Curran
# T20                         Virat Kohli
# CT                       Jacques Kallis
# CT                         Chris Cairns
# CT                                  NaN
# CT                         Ian Bradshaw
# CT                         Shane Watson
# CT                         Shane Watson
# CT                      Ravindra Jadeja
# CT                         Fakhar Zaman
# CT                         Rohit Sharma
# WTC                       Kyle Jamieson
# WTC                         Travis Head

# %%
df=icc.isna().sum().sort_values(ascending=False)/len(icc)*100
df
# Out:
# Win_By                 3.030303
# Player_of_the_Match    3.030303
# Tournament_Type        0.000000
# Year                   0.000000
# Host_Country           0.000000
# Winner                 0.000000
# Runner_Up              0.000000
# Winning_Captain        0.000000
# Final_Stadium          0.000000
# dtype: float64

# %%
icc
# Out:
#                              Tournament_Type    Year  \
# Tournament_Category
# ODI                            ODI World Cup  1975.0
# ODI                            ODI World Cup  1979.0
# ODI                            ODI World Cup  1983.0
# ODI                            ODI World Cup  1987.0
# ODI                            ODI World Cup  1992.0
# ODI                            ODI World Cup  1996.0
# ODI                            ODI World Cup  1999.0
# ODI                            ODI World Cup  2003.0
# ODI                            ODI World Cup  2007.0
# ODI                            ODI World Cup  2011.0
# ODI                            ODI World Cup  2015.0
# ODI                            ODI World Cup  2019.0
# ODI                            ODI World Cup  2023.0
# T20                            T20 World Cup  2007.0
# T20                            T20 World Cup  2009.0
# T20                            T20 World Cup  2010.0
# T20                            T20 World Cup  2012.0
# T20                            T20 World Cup  2014.0
# T20                            T20 World Cup  2016.0
# T20                            T20 World Cup  2021.0
# T20                            T20 World Cup  2022.0
# T20                            T20 World Cup  2024.0
# CT                          Champions Trophy  1998.0
# CT                          Champions Trophy  2000.0
# CT                          Champions Trophy  2002.0
# CT                          Champions Trophy  2004.0
# CT                          Champions Trophy  2006.0
# CT                          Champions Trophy  2009.0
# CT                          Champions Trophy  2013.0
# CT                          Champions Trophy  2017.0
# CT                          Champions Trophy  2025.0
# WTC                  World Test Championship  2021.0
# WTC                  World Test Championship  2023.0
#
#                                     Host_Country           Winner  \
# Tournament_Category
# ODI                                      England      West Indies
# ODI                                      England      West Indies
# ODI                                      England            India
# ODI                               India/Pakistan        Australia
# ODI                        Australia/New Zealand         Pakistan
# ODI                     India/Pakistan/Sri Lanka        Sri Lanka
# ODI                                      England        Australia
# ODI                  South Africa/Zimbabwe/Kenya        Australia
# ODI                                  West Indies        Australia
# ODI                   India/Sri Lanka/Bangladesh            India
# ODI                        Australia/New Zealand        Australia
# ODI                                England/Wales          England
# ODI                                        India        Australia
# T20                                 South Africa            India
# T20                                      England         Pakistan
# T20                                  West Indies          England
# T20                                    Sri Lanka      West Indies
# T20                                   Bangladesh        Sri Lanka
# T20                                        India      West Indies
# T20                                     UAE/Oman        Australia
# T20                                    Australia          England
# T20                              USA/West Indies            India
# CT                                    Bangladesh     South Africa
# CT                                         Kenya      New Zealand
# CT                                     Sri Lanka  India/Sri Lanka
# CT                                       England      West Indies
# CT                                         India        Australia
# CT                                  South Africa        Australia
# CT                                 England/Wales            India
# CT                                 England/Wales         Pakistan
# CT                                  Pakistan/UAE            India
# WTC                                      England      New Zealand
# WTC                                      England        Australia
#
#                                 Runner_Up      Winning_Captain  \
# Tournament_Category
# ODI                             Australia          Clive Lloyd
# ODI                               England          Clive Lloyd
# ODI                           West Indies            Kapil Dev
# ODI                               England         Allan Border
# ODI                               England           Imran Khan
# ODI                             Australia     Arjuna Ranatunga
# ODI                              Pakistan          Steve Waugh
# ODI                                 India        Ricky Ponting
# ODI                             Sri Lanka        Ricky Ponting
# ODI                             Sri Lanka             MS Dhoni
# ODI                           New Zealand       Michael Clarke
# ODI                           New Zealand          Eoin Morgan
# ODI                                 India          Pat Cummins
# T20                              Pakistan             MS Dhoni
# T20                             Sri Lanka          Younis Khan
# T20                             Australia     Paul Collingwood
# T20                             Sri Lanka         Darren Sammy
# T20                                 India     Dinesh Chandimal
# T20                               England         Darren Sammy
# T20                           New Zealand          Aaron Finch
# T20                              Pakistan          Jos Buttler
# T20                          South Africa         Rohit Sharma
# CT                            West Indies        Hansie Cronje
# CT                                  India      Stephen Fleming
# CT                   None (Joint Winners)  R Premadasa Stadium
# CT                                England           Brian Lara
# CT                            West Indies        Ricky Ponting
# CT                            New Zealand        Ricky Ponting
# CT                                England             MS Dhoni
# CT                                  India       Sarfaraz Ahmed
# CT                            New Zealand         Rohit Sharma
# WTC                                 India      Kane Williamson
# WTC                                 India          Pat Cummins
#
#                                            Final_Stadium          Win_By  \
# Tournament_Category
# ODI                                Lord's Cricket Ground         17 Runs
# ODI                                Lord's Cricket Ground         92 Runs
# ODI                                Lord's Cricket Ground         43 Runs
# ODI                                         Eden Gardens          7 Runs
# ODI                             Melbourne Cricket Ground         22 Runs
# ODI                                      Gaddafi Stadium       7 Wickets
# ODI                                Lord's Cricket Ground       8 Wickets
# ODI                                New Wanderers Stadium        125 Runs
# ODI                                      Kensington Oval         53 Runs
# ODI                                     Wankhede Stadium       6 Wickets
# ODI                             Melbourne Cricket Ground       7 Wickets
# ODI                                Lord's Cricket Ground  Boundary Count
# ODI                                Narendra Modi Stadium       6 Wickets
# T20                                The Wanderers Stadium          5 Runs
# T20                                Lord's Cricket Ground       8 Wickets
# T20                                      Kensington Oval       7 Wickets
# T20                                  R Premadasa Stadium         36 Runs
# T20                                Sher-e-Bangla Stadium       6 Wickets
# T20                                         Eden Gardens       4 Wickets
# T20                          Dubai International Stadium       8 Wickets
# T20                             Melbourne Cricket Ground       5 Wickets
# T20                                      Kensington Oval          7 Runs
# CT                          Bangabandhu National Stadium       4 Wickets
# CT                                  Gymkhana Club Ground       4 Wickets
# CT                                         Shared Trophy             NaN
# CT                                              The Oval       2 Wickets
# CT                                     Brabourne Stadium       8 Wickets
# CT                                        Centurion Park       6 Wickets
# CT                                             Edgbaston          5 Runs
# CT                                              The Oval        180 Runs
# CT                   Dubai International Cricket Stadium       4 Wickets
# WTC                                            Rose Bowl       8 Wickets
# WTC                                             The Oval        209 Runs
#
#                     Player_of_the_Match
# Tournament_Category
# ODI                         Clive Lloyd
# ODI                        Viv Richards
# ODI                   Mohinder Amarnath
# ODI                          David Boon
# ODI                         Wasim Akram
# ODI                   Aravinda de Silva
# ODI                         Shane Warne
# ODI                       Ricky Ponting
# ODI                      Adam Gilchrist
# ODI                            MS Dhoni
# ODI                      James Faulkner
# ODI                          Ben Stokes
# ODI                         Travis Head
# T20                        Irfan Pathan
# T20                       Shahid Afridi
# T20                    Craig Kieswetter
# T20                      Marlon Samuels
# T20                    Kumar Sangakkara
# T20                      Marlon Samuels
# T20                      Mitchell Marsh
# T20                          Sam Curran
# T20                         Virat Kohli
# CT                       Jacques Kallis
# CT                         Chris Cairns
# CT                                  NaN
# CT                         Ian Bradshaw
# CT                         Shane Watson
# CT                         Shane Watson
# CT                      Ravindra Jadeja
# CT                         Fakhar Zaman
# CT                         Rohit Sharma
# WTC                       Kyle Jamieson
# WTC                         Travis Head

# %% [markdown]
# **Insight**:
#
# Different missing value techniques were applied based on the nature and importance of each column to preserve data quality.
# Columns with unclear or unavailable information were filled using labels like “Unknown” or “Not Applicable,not recorded,Misc” to avoid losing valuable rows.
# This preprocessing step reduced missing data effectively, improved dataset consistency, and prepared the data for accurate analysis and machine learning.

# %% [markdown]
# ## Handling Duplicates

# %%
icc.duplicated().sum()
# Out:
# np.int64(0)

# %%
icc.shape
# Out:
# (33, 9)

# %% [markdown]
# **Insight**:
#
# - A total of 0 duplicate rows were identified, means no records had exactly the same values across all columns.
# - These duplicates likely occurred due to data entry errors, merging datasets, or repeated recordings of the same tournament.
# - Keeping duplicates can bias the analysis, as it over-represents certain patterns and affects model accuracy.
# - Removing them ensures data integrity, uniqueness, and more reliable statistical insights.
# - Hence, dropping duplicates improves the overall quality and fairness of the dataset for analysis and modeling.

# %% [markdown]
# ## Data Visualization and EDA

# %% [markdown]
# ## 1) Which country has won the most trophies overall?

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=icc, x="Winner", order=icc["Winner"].value_counts().index)
plt.title("Number of Trophies Won by Each Country")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Insight: Australia has won highest trophies in ODI.(5 Wins)

# %% [markdown]
# ## 2)  Do host countries often win?

# %%
# Data based on your analysis
labels = ["Host Won", "Host Did Not Won"]
sizes = [4, 30]   # 4 host wins, 30+ non-host wins
colors = ["lightgreen", "lightcoral"]

# Plot pie chart
plt.figure(figsize=(6,6))
plt.pie(sizes, labels=labels, autopct="%1.1f%%", colors=colors, startangle=90)
plt.title("Host Country Advantage in ICC Tournaments")
plt.show()

# %% [markdown]
# Insight: The chart will show about 11–12% host wins vs ~89% non-host wins, making it visually clear that home advantage is limited in ICC events.

# %% [markdown]
# ## 3) Which captains have won multiple trophies?

# %%
# Count trophies by winning captain
captains = icc['Winning_Captain'].value_counts().reset_index()
captains.columns = ['Captain', 'Trophies']
captains

# Filter only captains with more than 1 trophy
multi_captains = captains[captains['Trophies'] > 1]

plt.figure(figsize=(10,6))
sns.barplot(data=multi_captains, x="Captain", y="Trophies", palette="crest")

plt.title("Captains with Multiple ICC Trophies", fontsize=14)
plt.xlabel("Captains", fontsize=12)
plt.ylabel("Number of Trophies", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Insight**:
# - Ricky pointing has won mutiple ODI Trophies.

# %% [markdown]
# ## 4) Who are the most frequent “Player of the Match” winners in finals?

# %%
top_players = icc['Player_of_the_Match'].value_counts().head(10).reset_index()
top_players.columns = ['Player', 'Count']
top_players

plt.figure(figsize=(10,6))
sns.barplot(data=top_players,x='Player',y='Count',palette='mako')
plt.title("Top 10 Player of the Match Winners in ICC Finals", fontsize=14)
plt.xlabel('Player',fontsize=12)
plt.ylabel('Number of Awards',fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Insight**:
#
# Shane Watson (Australia) – Twice recognized, reflecting his all‑round dominance in crucial finals.
#
# Travis Head (Australia) – A modern standout, with two awards in recent ICC finals, showing his ability to deliver under pressure.
#
# Marlon Samuels (West Indies) – Twice awarded for match‑winning batting performances in T20 World Cup finals, proving his big‑match temperament

# %% [markdown]
# ## 5) What are the typical margins of victory (Runs vs Wickets)?

# %%
margin_counts = icc['Win_By'].value_counts().reset_index()
margin_counts.columns = ['Margin_Type', 'Count']

sns.lineplot(data=margin_counts, x="Margin_Type", y="Count", marker="o", linewidth=2, color="navy")
plt.title("Typical Margins of Victory in ICC Finals")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Insight**:
# - Wicket victories dominate — Wins by 8 wickets (5 times) and 6 wickets (4 times) are the most frequent, showing that chasing teams often finish strongly in finals.
# - Run victories are more varied — Margins range from small (5, 7, 17 runs) to massive (180, 209 runs), highlighting both close contests and one‑sided finals.

# %% [markdown]
# ## 6) How have winners changed over time?

# %%
wins_per_year = icc.groupby(["Year","Winner"]).size().reset_index(name="Count")

plt.figure(figsize=(12,6))
sns.lineplot(data=wins_per_year, x="Year", y="Count", hue="Winner", marker="o")
plt.title("ICC Tournament Wins Over Time by Country")
plt.show()

# %% [markdown]
# **Insight**:
#
# West Indies dominated early (1970s–80s).
#
# Australia had a golden run in the late 1990s–2000s.
#
# India & England have emerged strongly in recent years across formats.
#
# The timeline clearly shows how cricketing power has shifted across eras.

# %% [markdown]
# ## 7) How do different tournament types (ODI, T20, CT, WTC) compare?

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=icc, x="Tournament_Type", hue="Winner", palette="Set2")

plt.title("Comparison of Tournament Wins by Format", fontsize=14)
plt.xlabel("Tournament Type", fontsize=12)
plt.ylabel("Number of Wins", fontsize=12)
plt.xticks(rotation=45)
plt.legend(title="Winner", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# **Insight**:
#
# - Australia dominates ODIs, with six World Cup titles showcasing their long‑standing supremacy.
#
# - T20 World Cups are balanced, with West Indies, India, England, and Pakistan each leaving their mark.
#
# - Champions Trophy success is shared mainly between India and Australia, reflecting consistency in shorter multi‑team events.
#
# - WTC is still new, with New Zealand and Australia emerging as early leaders in the longest format.

# %% [markdown]
# ## Key Insights of Overall Project

# %% [markdown]
# 1. **Australia’s dynasty**:
#
# - They are the most successful team overall, with six ODI World Cups, two Champions Trophies, and the 2023 WTC — proving dominance across formats.
#
# 3. **Shifting eras of power**:
# - West Indies ruled the 1970s–80s, Australia in the 2000s, while India and England have emerged strongly in recent years, especially in T20s and CT.
#
# 3. **Leadership matters**:
# - Captains like Ricky Ponting, MS Dhoni, Darren Sammy, and Rohit Sharma stand out for guiding their teams to multiple ICC titles.
#
# 4. **Finals are decided by brilliance**:
# - Repeat “Player of the Match” winners (Marlon Samuels, Shane Watson, Travis Head) show how individual performances often tilt finals.
#
# 5. **Margins of victory vary**:
# - Chasing teams often win by large wicket margins (6–8 wickets), while defending sides produce both nail‑biting finishes (5–7 runs) and crushing wins (125+, 180+, 209 runs).
#
# 6. **Host advantage is rare**:
# - Only a few hosts (India 2011, England 2019) have lifted trophies at home, showing that conditions alone don’t guarantee success.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# - The ICC finals record highlights the evolution of cricket dominance across formats and eras. Australia stands out as the most successful team overall, building dynasties in ODIs and extending their success into CT and WTC.
# -  West Indies and India had breakthrough eras, with India’s resurgence in modern formats showing adaptability.
# -  T20 World Cups remain the most balanced, producing diverse champions, while WTC is still shaping its legacy.
# -  Leadership has been pivotal — captains like Ricky Ponting, MS Dhoni, Darren Sammy, and Rohit Sharma guided their sides to multiple titles.
# -  Finals often hinge on standout individual performances, with repeat “Player of the Match” winners underlining the role of brilliance in high‑pressure games.
# -  Margins of victory vary widely, but chasing teams frequently secure dominant wicket wins, while defending sides produce both close finishes and crushing run victories.

# %% [markdown]
# ## References / Bibliography
#
#
# #### Kaggle – ICC Tournament cricket Dataset
# - Used for collecting and understanding accident-related datasets for analysis.
#
#
# #### Pandas Documentation
# - Used for data cleaning, preprocessing, handling missing values, and dataframe operations.
#
#
# #### NumPy Documentation
# - Used for numerical computations and array operations during analysis.
#
#
# #### Matplotlib Documentation
# - Used for creating charts and visualizations in the project.
#
#
# #### Seaborn Documentation
# - Used for advanced statistical data visualization and plotting.
#
#
# #### Jupyter Notebook Documentation
# - Used as the development environment for coding and visualization.
#
#
# #### Python Official Documentation
# - Referred for Python syntax, functions, and programming concepts.
#
#
# #### OpenAI ChatGPT
# - Used for assistance in code verification, project documentation, data interpretation, and report writing.
#
#
# #### Google Gemini
# - Used for idea generation, concept understanding, and improving analytical explanations.
#
#
# #### GitHub Copilot
# - Used for coding assistance and debugging support during project development.
